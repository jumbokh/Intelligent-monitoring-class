# %%
import cv2
imagepath = "images/musk.jpg"
image = cv2.imread(imagepath)

# %% [markdown]
# ## 轉換成灰階圖片

# %%
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %% [markdown]
# ## 載入人臉分類器

# %%
classifier = "haarcascades/haarcascade_frontalface_default.xml" 
face_cascade = cv2.CascadeClassifier(classifier)

# %% [markdown]
# ## 識別人臉

# %%
#偵測圖片中的人臉
faces = face_cascade.detectMultiScale(image)

# %%
print("發現{0}個人臉!".format(len(faces)))
# Out:
# 發現1個人臉!

# %% [markdown]
# ## 秀圖, 人臉畫框

# %%
for(x,y,w,h) in faces:
   cv2.rectangle(image,(x,y),(x+w,y+w),(0,255,0),2)

# %% [markdown]
# ## 輸出圖片

# %%
# cv2.imshow("Image Title",image)

# %%
cv2.imwrite('output/output.jpg', image)
# Out:
# True

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('output/output.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=728x382 at 0x7F30B7238290>

# %%
imagepath = "images/musk.jpg"
image = cv2.imread(imagepath)

# %%
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_eye.xml')

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

# %%
for (x,y,w,h) in faces:
     img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
     roi_gray = gray[y:y+h, x:x+w]
     roi_color = img[y:y+h, x:x+w]
     eyes = eye_cascade.detectMultiScale(roi_gray)
     for (ex,ey,ew,eh) in eyes:
         cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)

# %%
cv2.imwrite('output/output.jpg', img)
# Out:
# True

# %%
from google.colab.patches import cv2_imshow
imgeye = cv2.imread('output/output.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(imgeye)
# Out:
# <PIL.Image.Image image mode=RGB size=728x382 at 0x7F30B5F484D0>
