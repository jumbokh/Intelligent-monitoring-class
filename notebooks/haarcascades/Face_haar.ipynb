# %%
import cv2
imagepath = "images/abba.png"
image = cv2.imread(imagepath)

# %% [markdown]
# ## 轉換成灰階圖片

# %%
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %% [markdown]
# ## 載入人臉分類器

# %%
classifier = "haarcascades/haarcascade_frontalface_default.xml" 
face_cascade = cv2.CascadeClassifier(classifier)

# %% [markdown]
# ## 識別人臉

# %%
#偵測圖片中的人臉
faces = face_cascade.detectMultiScale(image)

# %%
print("發現{0}個人臉!".format(len(faces)))
# Out:
# 发现4个人脸!

# %% [markdown]
# ## 秀圖, 人臉畫框

# %%
for(x,y,w,h) in faces:
   cv2.rectangle(image,(x,y),(x+w,y+w),(0,255,0),2)

# %% [markdown]
# ## 輸出圖片

# %%
# cv2.imshow("Image Title",image)

# %%
cv2.imwrite('output/output.jpg', image)
# Out:
# True

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('output/output.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x426 at 0x7F6C9C6DD6D0>
